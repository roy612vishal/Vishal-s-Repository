# %%
#Importing various libraries
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

# %%
#Loading the Datasets

# %%
train_data = pd.read_csv("train.csv")
ideal_data = pd.read_csv("ideal.csv")
test_data = pd.read_csv("test.csv")

# %%
print(train_data)
# Out:
#         x         y1         y2         y3          y4
# 0   -20.0 -45.292340 -15999.796  99.529580  899.827500
# 1   -19.9 -44.364960 -15761.017  99.895670  893.427400
# 2   -19.8 -44.565968 -15524.681  98.855780  887.160460
# 3   -19.7 -44.762450 -15290.500  98.126100  881.448700
# 4   -19.6 -44.188698 -15058.586  97.511475  875.377260
# ..    ...        ...        ...        ...         ...
# 395  19.5  34.150510  14829.701  97.719000   89.044914
# 396  19.6  33.875698  15058.578  98.092850   91.522880
# 397  19.7  33.952816  15291.142  98.500720   93.639630
# 398  19.8  34.517270  15524.978  99.343155   95.835785
# 399  19.9  34.639030  15761.660  99.192604   97.697480
#
# [400 rows x 5 columns]

# %%
print(ideal_data)
# Out:
#         x        y1        y2         y3        y4         y5        y6  \
# 0   -20.0 -0.912945  0.408082   9.087055  5.408082  -9.087055  0.912945
# 1   -19.9 -0.867644  0.497186   9.132356  5.497186  -9.132356  0.867644
# 2   -19.8 -0.813674  0.581322   9.186326  5.581322  -9.186326  0.813674
# 3   -19.7 -0.751573  0.659649   9.248426  5.659649  -9.248426  0.751573
# 4   -19.6 -0.681964  0.731386   9.318036  5.731386  -9.318036  0.681964
# ..    ...       ...       ...        ...       ...        ...       ...
# 395  19.5  0.605540  0.795815  10.605540  5.795815 -10.605540 -0.605540
# 396  19.6  0.681964  0.731386  10.681964  5.731386 -10.681964 -0.681964
# 397  19.7  0.751573  0.659649  10.751574  5.659649 -10.751574 -0.751573
# 398  19.8  0.813674  0.581322  10.813674  5.581322 -10.813674 -0.813674
# 399  19.9  0.867644  0.497186  10.867644  5.497186 -10.867644 -0.867644
#
#            y7        y8        y9  ...        y41        y42       y43  \
# ...

# %%
print(test_data)
# Out:
#        x             y
# 0  -13.1  -4494.980000
# 1    3.4     78.957020
# 2   11.1      2.493696
# 3    1.9  -7730.091300
# 4  -14.0  13840.699000
# ..   ...           ...
# 95  18.8   3417.366500
# 96  14.7     73.494940
# 97  13.2   5111.822800
# 98 -17.5    755.190500
# 99  12.2     59.622060
#
# [100 rows x 2 columns]

# %%
# Separating the features (x) and (y) in the training dataset

# %%
train_x = train_data[['x']]
train_y = train_data[['y1']]

# %%
print(train_x)
# Out:
#         x
# 0   -20.0
# 1   -19.9
# 2   -19.8
# 3   -19.7
# 4   -19.6
# ..    ...
# 395  19.5
# 396  19.6
# 397  19.7
# 398  19.8
# 399  19.9
#
# [400 rows x 1 columns]

# %%
print(train_y)
# Out:
#             y1
# 0   -45.292340
# 1   -44.364960
# 2   -44.565968
# 3   -44.762450
# 4   -44.188698
# ..         ...
# 395  34.150510
# 396  33.875698
# 397  33.952816
# 398  34.517270
# 399  34.639030
#
# [400 rows x 1 columns]

# %%
# Train a linear regression model
linear_reg = LinearRegression()
linear_reg.fit(train_x, train_y)
# Out:
# LinearRegression()

# %%
# Train a decision tree regression model

# %%
tree_reg = DecisionTreeRegressor()
tree_reg.fit(train_x, train_y)
# Out:
# DecisionTreeRegressor()

# %%
# Using the mean squared error (MSE) to evaluate the models.
train_y_pred_linear = linear_reg.predict(train_x)
train_y_pred_tree = tree_reg.predict(train_x)
linear_mse = mean_squared_error(train_y, train_y_pred_linear)
tree_mse = mean_squared_error(train_y, train_y_pred_tree)

# %%
# Print the models' MSEs.
print("Linear Regression MSE:", linear_mse)
print("Decision Tree Regression MSE:", tree_mse)
# Out:
# Linear Regression MSE: 0.08368237224993116
# Decision Tree Regression MSE: 0.0

# %%
# Visualize linear regression
plt.figure(figsize=(10, 6))
plt.scatter(train_x, train_y, color='blue', label='Actual')
plt.plot(train_x, train_y_pred_linear, color='red', linewidth=2, label='Linear Regression')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Linear Regression')
plt.legend()
plt.show()

# %%
# Visualize decision tree regression
plt.figure(figsize=(10, 6))
plot_tree(tree_reg, feature_names=['x'], filled=True)
plt.title('Decision Tree Regression')
plt.show()
